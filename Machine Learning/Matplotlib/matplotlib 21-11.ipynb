# %%
import numpy as np
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import randn, randint, uniform, sample
df = pd.DataFrame(randn(1000), index = pd.date_range('2019-06-07', periods = 1000), columns=['value'])

df.head()
# Out:
#                value
# 2019-06-07  0.778025
# 2019-06-08 -0.331815
# 2019-06-09 -1.014652
# 2019-06-10 -1.931830
# 2019-06-11  0.503178

# %%
ts = pd.Series(randn(1000), index = pd.date_range('2019-06-07', periods = 1000))
ts.head()
# Out:
# 2019-06-07   -0.202823
# 2019-06-08   -1.424698
# 2019-06-09   -1.661028
# 2019-06-10    0.949903
# 2019-06-11    0.935981
# Freq: D, dtype: float64

# %%
ts=ts.cumsum()
ts.head()
# Out:
# 2019-06-07   -0.202823
# 2019-06-08   -1.627521
# 2019-06-09   -3.288549
# 2019-06-10   -2.338646
# 2019-06-11   -1.402665
# Freq: D, dtype: float64

# %%
type(df), type(ts)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
ts.plot(figsize=(25,5))

# %%
fig=plt.figure(figsize=(7,5))
plt.plot(ts)
fig.savefig('xyz.png')

# %%
iris = sns.load_dataset('C:\Z\Z WorkspacePractice\ipynb\matplotlib\iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# 13            4.3          3.0           1.1          0.1     setosa
# 14            5.8          4.0           1.2          0.2     setosa
# 15            5.7          4.4           1.5          0.4     setosa
# 16            5.4          3.9           1.3          0.4     setosa
# 17            5.1          3.5           1.4          0.3     setosa
# 18            5.7          3.8           1.7          0.3     setosa
# 19            5.1          3.8           1.5          0.3     setosa
# 20            5.4          3.4           1.7          0.2     setosa
# 21            5.1          3.7           1.5          0.4     setosa
# 22            4.6          3.6           1.0          0.2     setosa
# 23            5.1          3.3           1.7          0.5     setosa
# 24            4.8          3.4           1.9          0.2     setosa
# 25            5.0          3.0           1.6          0.2     setosa
# 26            5.0          3.4           1.6          0.4     setosa
# 27            5.2          3.5           1.5          0.2     setosa
# 28            5.2          3.4           1.4          0.2     setosa
# 29            4.7          3.2           1.6          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 120           6.9          3.2           5.7          2.3  virginica
# 121           5.6          2.8           4.9          2.0  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 123           6.3          2.7           4.9          1.8  virginica
# 124           6.7          3.3           5.7          2.1  virginica
# 125           7.2          3.2           6.0          1.8  virginica
# 126           6.2          2.8           4.8          1.8  virginica
# 127           6.1          3.0           4.9          1.8  virginica
# 128           6.4          2.8           5.6          2.1  virginica
# 129           7.2          3.0           5.8          1.6  virginica
# 130           7.4          2.8           6.1          1.9  virginica
# 131           7.9          3.8           6.4          2.0  virginica
# 132           6.4          2.8           5.6          2.2  virginica
# 133           6.3          2.8           5.1          1.5  virginica
# 134           6.1          2.6           5.6          1.4  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 136           6.3          3.4           5.6          2.4  virginica
# 137           6.4          3.1           5.5          1.8  virginica
# 138           6.0          3.0           4.8          1.8  virginica
# 139           6.9          3.1           5.4          2.1  virginica
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 142           5.8          2.7           5.1          1.9  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
ax=iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
ts.plot(kind = 'bar')

# %%
df = iris.drop(['species'], axis = 1)

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='bar')

# %%
df.iloc[0].plot.bar()

# %%
df = pd.DataFrame(randn(10, 4), columns=['a', 'b', 'c', 'd'])
df.head(10)
# Out:
#           a         b         c         d
# 0 -0.718749  0.935258 -0.238938 -0.328347
# 1 -1.361482 -0.894301 -1.262893 -1.086840
# 2 -0.852546 -2.213080 -1.324272 -0.729125
# 3  0.677760 -0.516545 -1.067263  0.368827
# 4  1.097016 -1.258535 -0.716873  0.020662
# 5 -2.243320 -0.080377  0.797601 -0.811009
# 6  0.120753  0.071669  0.977351 -0.143280
# 7  0.370435  0.307661  0.891908  0.232158
# 8  1.202926 -0.380000  0.111484 -0.637071
# 9  0.865150 -1.545666  1.448605  1.912767

# %%
df.plot.bar()

# %%
df.plot(kind='bar')

# %%
df.plot.barh()

# %%
iris.plot.hist()

# %%
iris.plot(kind='hist',stacked = True, bins =10)

# %%
iris.plot(kind= 'hist', stacked = True, bins =50, orientation='horizontal')

# %%
iris['sepal_width'].diff()    #shows difference
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
# 5      0.3
# 6     -0.5
# 7      0.0
# 8     -0.5
# 9      0.2
# 10     0.6
# 11    -0.3
# 12    -0.4
# 13     0.0
# 14     1.0
# 15     0.4
# 16    -0.5
# 17    -0.4
# 18     0.3
# 19     0.0
# 20    -0.4
# 21     0.3
# 22    -0.1
# 23    -0.3
# 24     0.1
# 25    -0.4
# 26     0.4
# 27     0.1
# 28    -0.1
# 29    -0.2
#       ...
# 120    1.0
# 121   -0.4
# 122    0.0
# 123   -0.1
# 124    0.6
# 125   -0.1
# 126   -0.4
# 127    0.2
# 128   -0.2
# 129    0.2
# 130   -0.2
# 131    1.0
# 132   -1.0
# 133    0.0
# 134   -0.2
# 135    0.4
# 136    0.4
# 137   -0.3
# 138   -0.1
# 139    0.1
# 140    0.0
# 141    0.0
# 142   -0.4
# 143    0.5
# 144    0.1
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind = 'hist', stacked = True, bins = 50)

# %%
iris.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
df = iris.drop(['species'], axis = 1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df.diff().hist(color = 'b', alpha = 0.1, figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000029EB6150E10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000029EB6193B00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000029EB61C0048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000029EB61EA5C0>]],
#       dtype=object)

# %%
color = {'boxes': 'DarkGreen', 'whiskers': 'b'}
color
# Out:
# {'boxes': 'DarkGreen', 'whiskers': 'b'}

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length');
#df.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'Width', ax = ax, color = 'r')
#df.plot.scatter(x = 'sepal_width', y = 'petal_length', label = 'Width', ax = ax, color = 'g')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length',c = 'sepal_width', s = 100)

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 9, C = 'sepal_width')

# %%
d = df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize = (10,10))

# %%
d = df.head(3).T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots = True, figsize = (20, 20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000029EB87AC0B8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000029EB87D69E8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000029EB8941D30>],
#       dtype=object)

# %%
d.plot.pie(subplots = True, figsize = (20, 20), fontsize = 26, autopct = '%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000029EB89B4940>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000029EB8B92C18>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000029EB8BC1080>],
#       dtype=object)

# %%
series = pd.Series([0.2]*5, index = ['a','b','c', 'd','e'], name = 'Pie Plot')
series.plot.pie()

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df, figsize= (8,8), diagonal='kde', color = 'r')
plt.show()

# %%
ts.plot.kde()

# %%
from pandas.plotting import andrews_curves

# %%
andrews_curves(df, 'sepal_width')

# %%
ts.plot(style = 'r--', label = 'Series', legend = True)

# %%
df.plot(legend = True, figsize = (10, 5), logy = True)

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width]
# Index: []

# %%
x = df.drop(['sepal_width', 'petal_width'], axis = 1)
x.head()
# Out:
#    sepal_length  petal_length
# 0           5.1           1.4
# 1           4.9           1.4
# 2           4.7           1.3
# 3           4.6           1.5
# 4           5.0           1.4

# %%
y = df.drop(['sepal_length', 'petal_length'], axis = 1)
y.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
ax = x.plot()
y.plot(figsize = (16,10), secondary_y=True, ax = ax)

# %%
x.plot(figsize=(10,5), x_compat = True)

# %%
df.plot(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000029EBD2C9128>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000029EBCF9E198>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000029EBCFC4550>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000029EBCFEC9B0>],
#       dtype=object)

# %%
df.plot(subplots = True, sharex = True, layout = (2,3), figsize = (16,8))
plt.tight_layout()
